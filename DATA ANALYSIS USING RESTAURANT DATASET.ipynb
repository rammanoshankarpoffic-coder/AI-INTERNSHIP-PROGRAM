# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv("/content/drive/MyDrive/Dataset/i1.csv")
df2 = pd.read_csv("/content/drive/MyDrive/Dataset/i2.csv")

# %%
merdf = df1.merge(df2,how='outer')

# %%
merdf.tail()
# Out:
#              Date            Timestamp  Invoice No.             Item Name  \
# 15616  2023-09-19  2023-09-19 22:03:44        28389                Kulcha
# 15617  2023-09-19  2023-09-19 22:03:44        28389         Mineral Water
# 15618  2023-09-19  2023-09-19 22:03:44        28389       Mushroom Masala
# 15619  2023-09-19  2023-09-19 22:03:44        28389  Paneer Butter Masala
# 15620  2023-09-19  2023-09-19 22:03:44        28389                Parota
#
#        Price  Qty.  Sub Total  Discount   Tax  Final Total  Table No.  \
# 15616   55.0   1.0       55.0       0.0  2.76        57.76       16.0
# 15617   20.0   2.0       40.0       0.0  2.00        42.00       16.0
# 15618  150.0   1.0      150.0       0.0  7.50       157.50       16.0
# 15619  150.0   1.0      150.0       0.0  7.50       157.50       16.0
# 15620   30.0   4.0      120.0       0.0  6.00       126.00       16.0
#
#       Server Name  Covers Variation             Category  HSN
# ...

# %%
merdf.head()
# Out:
#          Date            Timestamp  Invoice No.                    Item Name  \
# 0  2023-04-01  2023-04-01 13:16:03        23465          Babycorn Manchurian
# 1  2023-04-01  2023-04-01 13:16:03        23465            Chicken Kati Roll
# 2  2023-04-01  2023-04-01 13:16:03        23465         Paneer Butter Masala
# 3  2023-04-01  2023-04-01 13:16:03        23465                 Pulka (2 No)
# 4  2023-04-01  2023-04-01 13:16:03        23465  Schewan  Chicken Fried Rice
#
#    Price  Qty.  Sub Total  Discount   Tax  Final Total  Table No. Server Name  \
# 0  160.0   1.0      160.0       0.0   8.0        168.0       20.0      biller
# 1  120.0   1.0      120.0       0.0   6.0        126.0       20.0      biller
# 2  150.0   2.0      300.0       0.0  15.0        315.0       20.0      biller
# 3   40.0   3.0      120.0       0.0   6.0        126.0       20.0      biller
# 4  160.0   1.0      160.0       0.0   8.0        168.0       20.0      biller
#
# ...

# %%
merdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15621 entries, 0 to 15620
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         15621 non-null  object
#  1   Timestamp    15621 non-null  object
#  2   Invoice No.  15621 non-null  int64
#  3   Item Name    15621 non-null  object
#  4   Price        15621 non-null  float64
#  5   Qty.         15621 non-null  float64
#  6   Sub Total    15621 non-null  float64
#  7   Discount     15621 non-null  float64
#  8   Tax          15621 non-null  float64
#  9   Final Total  15621 non-null  float64
#  10  Table No.    15613 non-null  float64
#  11  Server Name  15621 non-null  object
#  12  Covers       15621 non-null  int64
#  13  Variation    15 non-null     object
#  14  Category     15621 non-null  object
#  15  HSN          0 non-null      float64
# dtypes: float64(8), int64(2), object(6)
# memory usage: 1.9+ MB

# %%
merdf.shape
# Out:
# (15621, 16)

# %%
merdf.describe()
# Out:
#         Invoice No.         Price          Qty.     Sub Total      Discount  \
# count  15621.000000  15621.000000  15621.000000  15621.000000  15621.000000
# mean   25989.963127    116.608988      1.338839    147.407080      1.262818
# std     1433.192998     63.663769      0.949814    210.127442      6.656396
# min    23465.000000     12.000000      1.000000     12.000000      0.000000
# 25%    24751.000000     50.000000      1.000000     80.000000      0.000000
# 50%    25980.000000    140.000000      1.000000    150.000000      0.000000
# 75%    27274.000000    160.000000      1.000000    170.000000      0.000000
# max    28389.000000    770.000000     28.000000  21560.000000    288.000000
#
#                 Tax   Final Total     Table No.   Covers  HSN
# count  15621.000000  15621.000000  15613.000000  15621.0  0.0
# mean       7.303668    153.447930     18.068340      0.0  NaN
# std       10.461474    219.678163     17.191377      0.0  NaN
# ...

# %%
merdf.isnull().sum()
# Out:
# Date               0
# Timestamp          0
# Invoice No.        0
# Item Name          0
# Price              0
# Qty.               0
# Sub Total          0
# Discount           0
# Tax                0
# Final Total        0
# Table No.          8
# Server Name        0
# Covers             0
# Variation      15606
# Category           0
# HSN            15621
# dtype: int64

# %%
Reqdf = merdf.drop(["Discount","Table No.","Server Name","Covers","Variation","HSN"],axis=1)

# %%
Reqdf.shape
# Out:
# (15621, 10)

# %%
sum=Reqdf["Final Total"].sum()
print(sum)
# Out:
# 2397010.12

# %%
uni = Reqdf["Invoice No."].nunique()
print(uni)
# Out:
# 4925

# %%
avg = sum/uni
print(avg)
# Out:
# 486.70256243654825

# %%
maxquan = Reqdf.groupby('Item Name')["Qty."].sum().sort_values(ascending=False)
maxquan
# Out:
# Item Name
# Mineral Water                             1672.0
# Chicken Biriyani With Raitha And Gravy    1453.0
# Butter Naan                               1046.0
# Romali Roti (1 No)                         822.0
# Lemon Soda                                 722.0
#                                            ...
# Chicken Malai Kebab                          1.0
# Soft Drinks Tin                              1.0
# Veg Pulav                                    1.0
# American Chopsey( Veg)                       1.0
# Aalu Mutter Masala                           1.0
# Name: Qty., Length: 270, dtype: float64

# %%
Top5 = Reqdf.groupby('Item Name')["Qty."].sum().sort_values(ascending=False)[0:5]
print(Top5)
# Out:
# Item Name
# Mineral Water                             1672.0
# Chicken Biriyani With Raitha And Gravy    1453.0
# Butter Naan                               1046.0
# Romali Roti (1 No)                         822.0
# Lemon Soda                                 722.0
# Name: Qty., dtype: float64

# %%
sns.barplot(Top5)
# Out:
# <Axes: xlabel='Item Name', ylabel='Qty.'>

# %%
Top5.plot(kind='bar')
# Out:
# <Axes: xlabel='Item Name'>

# %%
saletop10 = Reqdf.groupby('Item Name')["Final Total"].sum().sort_values(ascending=False)[0:11]
print(saletop10)
# Out:
# Item Name
# Chicken Biriyani With Raitha And Gravy    240730.96
# Chicken Fried Rice                        119347.20
# Butter Naan                                65387.74
# Thandoor Chicken Half                      53185.83
# Paneer Butter Masala                       49581.22
# Chicken Lolly Pop                          48437.66
# Chicken 65                                 48281.92
# Pepper Tandoori Chicken ( Half )           45886.61
# Dragon Chicken                             44219.72
# Butter Chicken Gravy                       44098.58
# Egg Fried Rice                             43398.92
# Name: Final Total, dtype: float64

# %%
saletop10.plot(kind='bar')
# Out:
# <Axes: xlabel='Item Name'>

# %%
datesale = Reqdf.groupby('Date')["Final Total"].sum().sort_values(ascending=True)
print(datesale)
# Out:
# Date
# 2023-05-02     3489.18
# 2023-06-20     5247.88
# 2023-07-03     5414.88
# 2023-06-28     5796.04
# 2023-06-05     5948.16
#                 ...
# 2023-06-10    24243.19
# 2023-08-11    24271.78
# 2023-06-09    27167.70
# 2023-05-19    29690.16
# 2023-04-13    31154.64
# Name: Final Total, Length: 171, dtype: float64

# %%
Reqdf[Reqdf['Date'] == '2023-09-15']['Final Total'].sum()
# Out:
# np.float64(21042.02)

# %%
Reqdf[(Reqdf['Date'] == '2023-09-15') & (Reqdf['Item Name'] == 'Chicken Noodles')]['Qty.'].sum()
# Out:
# np.float64(7.0)

# %%
newvar = Reqdf.groupby('Invoice No.')["Final Total"].sum()
newvar[newvar > 2000]
# Out:
# Invoice No.
# 23499     2533.64
# 23508     2011.00
# 23637     5644.82
# 23718     3517.50
# 23827    22638.00
#            ...
# 28014     3013.68
# 28126     2887.50
# 28145     4078.68
# 28259     4291.36
# 28315     2004.44
# Name: Final Total, Length: 162, dtype: float64

# %%
newvar = Reqdf.groupby('Invoice No.')["Final Total"].sum()
newvar[newvar == 2887.50]
# Out:
# Invoice No.
# 28126    2887.5
# Name: Final Total, dtype: float64

# %%
Reqdf[Reqdf['Invoice No.'] == 28145][['Item Name','Qty.','Final Total']].sum()
# Out:
# Item Name      Butter Chicken GravyButter Chicken GravyButter...
# Qty.                                                        40.0
# Final Total                                              4078.68
# dtype: object

# %%
from IPython.core.pylabtools import figsize
from wordcloud import WordCloud

text  = ' '.join(Reqdf['Item Name'].dropna().astype(str).values)

wordcloud = WordCloud(background_color='white',width = 800,height=400).generate(text)

fig , ax = plt.subplots(figsize=(10,6))

ax.imshow(wordcloud, interpolation = 'bilinear')
ax.set_title('Word Cloud of the Item Column')
ax.set_xticks([])
ax.set_yticks([])
plt.show()

# %%
from IPython.core.pylabtools import figsize
from wordcloud import WordCloud

text  = ' '.join(Reqdf['Item Name'].dropna().astype(str).values)

wordcloud = WordCloud(background_color='white',width = 800,height=400).generate(text)

fig , ax = plt.subplots(figsize=(10,6))

ax.imshow(wordcloud, interpolation = 'Nearest')
ax.set_title('Word Cloud of the Item Column')
ax.set_xticks([])
ax.set_yticks([])
plt.show()

# %%
from IPython.core.pylabtools import figsize
from wordcloud import WordCloud

text  = ' '.join(Reqdf['Item Name'].dropna().astype(str).values)

wordcloud = WordCloud(background_color='white',width = 800,height=400).generate(text)

fig , ax = plt.subplots(figsize=(10,6))

ax.imshow(wordcloud, interpolation = 'Bicubic')
ax.set_title('Word Cloud of the Item Column')
ax.set_xticks([])
ax.set_yticks([])
plt.show()

# %%
from IPython.core.pylabtools import figsize
from wordcloud import WordCloud

text  = ' '.join(Reqdf['Item Name'].dropna().astype(str).values)

wordcloud = WordCloud(background_color='white',width = 800,height=400).generate(text)

fig , ax = plt.subplots(figsize=(10,6))

ax.imshow(wordcloud, interpolation = 'lanczos')
ax.set_title('Word Cloud of the Item Column')
ax.set_xticks([])
ax.set_yticks([])
plt.show()

# %%
from IPython.core.pylabtools import figsize
from wordcloud import WordCloud

text  = ' '.join(Reqdf['Item Name'].dropna().astype(str).values)

wordcloud = WordCloud(background_color='white',width = 800,height=400).generate(text)

fig , ax = plt.subplots(figsize=(10,6))

ax.imshow(wordcloud, interpolation = 'spline36')
ax.set_title('Word Cloud of the Item Column')
ax.set_xticks([])
ax.set_yticks([])
plt.show()
